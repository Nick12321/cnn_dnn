# %%
# Setting up MNST, this should look familiar:
from matplotlib import pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.layers import LeakyReLU
from keras.layers import Dense, Dropout

mnist_num_classes = 10 
mnist_image_size = 784

(mnist_training_images, mnist_training_labels), (mnist_test_images, mnist_test_labels) = mnist.load_data()
mnist_training_data = mnist_training_images.reshape(mnist_training_images.shape[0], mnist_image_size) 
mnist_test_data = mnist_test_images.reshape(mnist_test_images.shape[0], mnist_image_size)

mnist_training_labels = to_categorical(mnist_training_labels, mnist_num_classes)
mnist_test_labels = to_categorical(mnist_test_labels, mnist_num_classes)
# Out:
# Using TensorFlow backend.

# %%
def plot_training_history(history, model, name, time):
    figure = plt.figure()
    figure.suptitle(name)
    plt.subplot(1, 2, 1)
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['training', 'validation'], loc='best')
    plt.tight_layout()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['training', 'validation'], loc='best')
    plt.tight_layout()

    figure.tight_layout()
    plt.show()
    
    loss, accuracy  = model.evaluate(mnist_test_data, mnist_test_labels, verbose=False)
    print(f'Trained in {time} seconds')
    print(f'Test loss: {loss:.3}')
    print(f'Test accuracy: {accuracy:.3}')

# %%
# Our model to achieve 97% ++:
def nick_model():
    model_2 = Sequential()
    model_2.add(Dense(units=64, activation='relu', input_shape=(mnist_image_size,)))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=mnist_num_classes, activation='softmax'))
    
    return model_2

# %%
import time # Because we care about the speed of these optimizers too!

name = "sgd"
model = nick_model()
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
start = time.process_time()
history = model.fit(mnist_training_data, mnist_training_labels, batch_size=128, epochs=20, verbose=False, validation_split=.1)
stop = time.process_time()
plot_training_history(history, model, name, stop - start)
# Out:
# Trained in 35.57018330699998 seconds
# Test loss: 0.171
# Test accuracy: 0.96

# %%
 def nick_model_2():
    model_2 = Sequential()
    model_2.add(Dense(units=256, activation='relu', input_shape=(mnist_image_size,)))
    model_2.add(Dense(units=128, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=mnist_num_classes, activation='softmax'))
    
    return model_2

# %%
import time # Because we care about the speed of these optimizers too!

name = "sgd"
model = nick_model_2()
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
start = time.process_time()
history = model.fit(mnist_training_data, mnist_training_labels, batch_size=128, epochs=20, verbose=False, validation_split=.1)
stop = time.process_time()
plot_training_history(history, model, name, stop - start)
# Out:
# Trained in 81.2854900939999 seconds
# Test loss: 0.179
# Test accuracy: 0.965

# %%
def nick_model_2():
    model_2 = Sequential()
    model_2.add(Dense(units=128, activation='relu', input_shape=(mnist_image_size,)))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=mnist_num_classes, activation='softmax'))
    
    return model_2

# %%
import time # Because we care about the speed of these optimizers too!

name = "sgd"
model = nick_model_2()
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
start = time.process_time()
history = model.fit(mnist_training_data, mnist_training_labels, batch_size=128, epochs=20, verbose=False, validation_split=.1)
stop = time.process_time()
plot_training_history(history, model, name, stop - start)
# Out:
# Trained in 46.131567197000095 seconds
# Test loss: 0.199
# Test accuracy: 0.955

# %%
def nick_model_2():
    model_2 = Sequential()
    model_2.add(Dense(units=256, activation='relu', input_shape=(mnist_image_size,)))
    model_2.add(Dense(units=128, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=64, activation='relu'))
    model_2.add(Dense(units=32, activation='relu'))
    model_2.add(Dense(units=32, activation='relu'))
    model_2.add(Dense(units=mnist_num_classes, activation='softmax'))
    
    return model_2

# %%
import time # Because we care about the speed of these optimizers too!

name = "sgd"
model = nick_model_2()
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
start = time.process_time()
history = model.fit(mnist_training_data, mnist_training_labels, batch_size=128, epochs=20, verbose=False, validation_split=.1)
stop = time.process_time()
plot_training_history(history, model, name, stop - start)
# Out:
# Trained in 80.88211268300006 seconds
# Test loss: 0.173
# Test accuracy: 0.966

# %%
def nick_model_2():
    model_2 = Sequential()
    model_2.add(Dense(units=256, activation='LeakyReLU(alpha=.01)', input_shape=(mnist_image_size,)))
    model_2.add(Dense(units=128, activation='LeakyReLU(alpha=.01)'))
    model_2.add(Dense(units=64, activation='LeakyReLU(alpha=.01)'))
    model_2.add(Dense(units=64, activation='LeakyReLU(alpha=.01)'))
    model_2.add(Dense(units=32, activation='LeakyReLU(alpha=.01)'))
    model_2.add(Dense(units=32, activation='LeakyReLU(alpha=.01)'))
    model_2.add(Dense(units=mnist_num_classes, activation='softmax'))
    
    return model_2

# %%
import time # Because we care about the speed of these optimizers too!

name = "sgd"
model = nick_model_2()
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
start = time.process_time()
history = model.fit(mnist_training_data, mnist_training_labels, batch_size=128, epochs=20, verbose=False, validation_split=.1)
stop = time.process_time()
plot_training_history(history, model, name, stop - start)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-9e52798d2243> in <module>
#       2
#       3 name = "sgd"
# ----> 4 model = nick_model_2()
#       5 model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
#       6 start = time.process_time()
#
# <ipython-input-22-069aa3a35f48> in nick_model_2()
#       3 def nick_model_2():
#       4     model_2 = Sequential()
# ----> 5     model_2.add(Dense(units=256, activation='LeakyReLU(alpha=.01)', input_shape=(mnist_image_size,)))
#       6     model_2.add(Dense(units=128, activation='LeakyReLU(alpha=.01)'))
#       7     model_2.add(Dense(units=64, activation='LeakyReLU(alpha=.01)'))
#
# ~/.local/share/virtualenvs/intro-to-deep-learning-JvewHh9U/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.local/share/virtualenvs/intro-to-deep-learning-JvewHh9U/lib/python3.7/site-packages/keras/layers/core.py in __init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     844         super(Dense, self).__init__(**kwargs)
#     845         self.units = units
# --> 846         self.activation = activations.get(activation)
#     847         self.use_bias = use_bias
#     848         self.kernel_initializer = initializers.get(kernel_initializer)
#
# ~/.local/share/virtualenvs/intro-to-deep-learning-JvewHh9U/lib/python3.7/site-packages/keras/activations.py in get(identifier)
#     201     if isinstance(identifier, six.string_types):
#     202         identifier = str(identifier)
# --> 203         return deserialize(identifier)
#     204     elif callable(identifier):
#     205         if isinstance(identifier, Layer):
#
# ~/.local/share/virtualenvs/intro-to-deep-learning-JvewHh9U/lib/python3.7/site-packages/keras/activations.py in deserialize(name, custom_objects)
#     182         module_objects=globals(),
#     183         custom_objects=custom_objects,
# --> 184         printable_module_name='activation function')
#     185
#     186
#
# ~/.local/share/virtualenvs/intro-to-deep-learning-JvewHh9U/lib/python3.7/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     163             if fn is None:
#     164                 raise ValueError('Unknown ' + printable_module_name +
# --> 165                                  ':' + function_name)
#     166         return fn
#     167     else:
#
# ValueError: Unknown activation function:LeakyReLU(alpha=.01)

# %%
# %time a = range(10)
# Out:
# CPU times: user 7 µs, sys: 2 µs, total: 9 µs
# Wall time: 13.6 µs

# %%
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?

# %%
min(a)
# Out:
# 0

# %%
# %%timeit a = range (10)
# Out:
# UsageError: %%timeit is a cell magic, but the cell body is empty. Did you mean the line magic %timeit (single %)?
